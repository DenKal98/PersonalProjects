# %%
import pandas as pd
import numpy as np
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score, confusion_matrix
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.model_selection import KFold
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score

# %%
data = pd.read_csv('final_data.csv')
X = data.iloc[:, 1: -1]
Y = data.iloc[:, -1]

# %%
sm = SMOTE(random_state=42)
X_train_res, y_train_res = sm.fit_resample(X, Y)
train, test, y_train, y_test = train_test_split(X_train_res,y_train_res, test_size=0.2, random_state=100)
train, val, y_train, y_val = train_test_split(train,y_train,test_size=0.25)

# %%
folds = KFold(n_splits=5)
folds.split(X)
xgb_c1 = XGBClassifier()
for train_index, test_index in folds.split(X):
    # Split train-test
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = Y[train_index], Y[test_index]
    xgb_c1.fit(X_train, y_train)
    y_pred = xgb_c1.predict(X_test)

# %%
xgb_c1 = XGBClassifier(subsample=0.5,samplingmethod='gradient_based')
xgb_c1.fit(train, y_train,eval_set=[(train, y_train), (val, y_val)])
y_pred = xgb_c1.predict(test)
    

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
acc = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
print('Precision:', precision)
print('Recall:', recall)
print('Accuracy:', acc)
print('Confusion Matrix:', cm)
# Out:
# [0]	validation_0-error:0.136286	validation_1-error:0.13402
# [1]	validation_0-error:0.124885	validation_1-error:0.12401
# [2]	validation_0-error:0.136085	validation_1-error:0.13386
# [3]	validation_0-error:0.125533	validation_1-error:0.124367
# [4]	validation_0-error:0.11778	validation_1-error:0.116044
# [5]	validation_0-error:0.099698	validation_1-error:0.097933
# [6]	validation_0-error:0.098832	validation_1-error:0.09664
# [7]	validation_0-error:0.093451	validation_1-error:0.091383
# [8]	validation_0-error:0.090069	validation_1-error:0.089031
# [9]	validation_0-error:0.091337	validation_1-error:0.089844
# [10]	validation_0-error:0.09034	validation_1-error:0.088588
# [11]	validation_0-error:0.088547	validation_1-error:0.086975
# [12]	validation_0-error:0.088181	validation_1-error:0.086827
# [13]	validation_0-error:0.08331	validation_1-error:0.081988
# [14]	validation_0-error:0.078085	validation_1-error:0.076608
# [15]	validation_0-error:0.076103	validation_1-error:0.074625
# [16]	validation_0-error:0.072569	validation_1-error:0.071695
# [17]	validation_0-error:0.068982	validation_1-error:0.067977
# [18]	validation_0-error:0.066626	validation_1-error:0.0656
# [19]	validation_0-error:0.065789	validation_1-error:0.064899
# [20]	validation_0-error:0.063901	validation_1-error:0.063113
# [21]	validation_0-error:0.06132	validation_1-error:0.060405
# [22]	validation_0-error:0.058755	validation_1-error:0.057043
# [23]	validation_0-error:0.05745	validation_1-error:0.055984
# [24]	validation_0-error:0.056645	validation_1-error:0.055246
# [25]	validation_0-error:0.053284	validation_1-error:0.052106
# [26]	validation_0-error:0.053341	validation_1-error:0.052106
# [27]	validation_0-error:0.052496	validation_1-error:0.051195
# [28]	validation_0-error:0.049533	validation_1-error:0.04856
# [29]	validation_0-error:0.049245	validation_1-error:0.047932
# [30]	validation_0-error:0.047493	validation_1-error:0.046652
# [31]	validation_0-error:0.047029	validation_1-error:0.046245
# [32]	validation_0-error:0.04526	validation_1-error:0.044669
# [33]	validation_0-error:0.045498	validation_1-error:0.044719
# [34]	validation_0-error:0.04487	validation_1-error:0.044251
# [35]	validation_0-error:0.044554	validation_1-error:0.043697
# [36]	validation_0-error:0.043114	validation_1-error:0.042133
# [37]	validation_0-error:0.042667	validation_1-error:0.041874
# [38]	validation_0-error:0.041858	validation_1-error:0.040803
# [39]	validation_0-error:0.041665	validation_1-error:0.040385
# [40]	validation_0-error:0.041374	validation_1-error:0.040101
# [41]	validation_0-error:0.04061	validation_1-error:0.039634
# [42]	validation_0-error:0.040159	validation_1-error:0.039363
# [43]	validation_0-error:0.039802	validation_1-error:0.038858
# [44]	validation_0-error:0.039326	validation_1-error:0.03839
# [45]	validation_0-error:0.038525	validation_1-error:0.037664
# [46]	validation_0-error:0.037836	validation_1-error:0.036876
# [47]	validation_0-error:0.037491	validation_1-error:0.036555
# [48]	validation_0-error:0.037027	validation_1-error:0.036223
# [49]	validation_0-error:0.036728	validation_1-error:0.035767
# [50]	validation_0-error:0.036441	validation_1-error:0.035521
# [51]	validation_0-error:0.035964	validation_1-error:0.035115
# [52]	validation_0-error:0.035829	validation_1-error:0.035078
# [53]	validation_0-error:0.035558	validation_1-error:0.034795
# [54]	validation_0-error:0.035176	validation_1-error:0.034155
# [55]	validation_0-error:0.034852	validation_1-error:0.033945
# [56]	validation_0-error:0.03454	validation_1-error:0.033724
# [57]	validation_0-error:0.034294	validation_1-error:0.033625
# [58]	validation_0-error:0.034105	validation_1-error:0.033256
# [59]	validation_0-error:0.033806	validation_1-error:0.033096
# [60]	validation_0-error:0.033613	validation_1-error:0.03296
# [61]	validation_0-error:0.033387	validation_1-error:0.032739
# [62]	validation_0-error:0.033133	validation_1-error:0.032431
# [63]	validation_0-error:0.032702	validation_1-error:0.032098
# [64]	validation_0-error:0.032312	validation_1-error:0.031791
# [65]	validation_0-error:0.031951	validation_1-error:0.031446
# [66]	validation_0-error:0.031741	validation_1-error:0.0312
# [67]	validation_0-error:0.031553	validation_1-error:0.030966
# [68]	validation_0-error:0.031273	validation_1-error:0.030732
# [69]	validation_0-error:0.031027	validation_1-error:0.030596
# [70]	validation_0-error:0.030793	validation_1-error:0.030449
# [71]	validation_0-error:0.030621	validation_1-error:0.030301
# [72]	validation_0-error:0.030293	validation_1-error:0.029882
# [73]	validation_0-error:0.03012	validation_1-error:0.029697
# [74]	validation_0-error:0.029985	validation_1-error:0.029525
# [75]	validation_0-error:0.029927	validation_1-error:0.029488
# [76]	validation_0-error:0.029792	validation_1-error:0.029143
# [77]	validation_0-error:0.02964	validation_1-error:0.029106
# [78]	validation_0-error:0.029492	validation_1-error:0.028836
# [79]	validation_0-error:0.02925	validation_1-error:0.028749
# [80]	validation_0-error:0.029086	validation_1-error:0.028454
# [81]	validation_0-error:0.028901	validation_1-error:0.028479
# [82]	validation_0-error:0.028811	validation_1-error:0.02838
# [83]	validation_0-error:0.028635	validation_1-error:0.028245
# [84]	validation_0-error:0.028458	validation_1-error:0.028035
# [85]	validation_0-error:0.028265	validation_1-error:0.028035
# [86]	validation_0-error:0.028425	validation_1-error:0.028097
# [87]	validation_0-error:0.028195	validation_1-error:0.027912
# [88]	validation_0-error:0.028015	validation_1-error:0.027826
# [89]	validation_0-error:0.027949	validation_1-error:0.027604
# [90]	validation_0-error:0.027703	validation_1-error:0.027432
# [91]	validation_0-error:0.027494	validation_1-error:0.027112
# [92]	validation_0-error:0.027305	validation_1-error:0.02705
# [93]	validation_0-error:0.027116	validation_1-error:0.026927
# [94]	validation_0-error:0.02703	validation_1-error:0.026632
# [95]	validation_0-error:0.026976	validation_1-error:0.026595
# [96]	validation_0-error:0.02687	validation_1-error:0.026484
# [97]	validation_0-error:0.026644	validation_1-error:0.02625
# [98]	validation_0-error:0.026414	validation_1-error:0.026152
# [99]	validation_0-error:0.026332	validation_1-error:0.025955
# Precision: 0.9683993699260874
# Recall: 0.9822771741802271
# Accuracy: 0.9750677173110072
# Confusion Matrix: [[39234  1304]
#  [  721 39961]]

# %%
print('Roc-auc score',roc_auc_score(y_test, y_pred))
# Out:
# Roc-auc score 0.9750549125131733

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 1, 1], dtype=int64)

# %%
kfold = KFold(n_splits=10)
pred = []
train, test, y_train, y_test = train_test_split(X, Y, test_size = 0.1,random_state = 42)
for train_ind, test_ind in kfold.split(train):
    train_val, test_val, y_train_val, y_test_val = train.iloc[train_ind, :], train.iloc[test_ind, :],\
                                                   y_train.iloc[train_ind], y_train.iloc[test_ind]
    xgb_c1.fit(train_val, y_train_val,eval_set=[(train, y_train), (test_val, y_test_val)])
    prediction = xgb_c1.predict_proba(test)
    pred.append(
    prediction[:, 1]
    )
    

print('Roc-auc score with Catboost:',roc_auc_score(y_test, np.mean(pred, axis = 0)))
# Out:
# [0]	validation_0-error:0.052311	validation_1-error:0.053873
# [1]	validation_0-error:0.052433	validation_1-error:0.054069
# [2]	validation_0-error:0.051745	validation_1-error:0.053336
# [3]	validation_0-error:0.051715	validation_1-error:0.053189
# [4]	validation_0-error:0.051735	validation_1-error:0.053189
# [5]	validation_0-error:0.053527	validation_1-error:0.054801
# [6]	validation_0-error:0.053361	validation_1-error:0.054997
# [7]	validation_0-error:0.053987	validation_1-error:0.055876
# [8]	validation_0-error:0.056815	validation_1-error:0.058611
# [9]	validation_0-error:0.057215	validation_1-error:0.058806
# [10]	validation_0-error:0.057528	validation_1-error:0.059197
# [11]	validation_0-error:0.056614	validation_1-error:0.058269
# [12]	validation_0-error:0.056033	validation_1-error:0.057878
# [13]	validation_0-error:0.055838	validation_1-error:0.058171
# [14]	validation_0-error:0.054372	validation_1-error:0.056364
# [15]	validation_0-error:0.054851	validation_1-error:0.056804
# [16]	validation_0-error:0.055276	validation_1-error:0.057243
# [17]	validation_0-error:0.053103	validation_1-error:0.055778
# [18]	validation_0-error:0.051906	validation_1-error:0.053922
# [19]	validation_0-error:0.050802	validation_1-error:0.053189
# [20]	validation_0-error:0.050695	validation_1-error:0.053434
# [21]	validation_0-error:0.050055	validation_1-error:0.05275
# [22]	validation_0-error:0.050265	validation_1-error:0.053043
# [23]	validation_0-error:0.050206	validation_1-error:0.052701
# [24]	validation_0-error:0.049117	validation_1-error:0.052066
# [25]	validation_0-error:0.048926	validation_1-error:0.051773
# [26]	validation_0-error:0.048331	validation_1-error:0.051285
# [27]	validation_0-error:0.047827	validation_1-error:0.05021
# [28]	validation_0-error:0.047183	validation_1-error:0.04977
# [29]	validation_0-error:0.046841	validation_1-error:0.049184
# [30]	validation_0-error:0.04646	validation_1-error:0.048989
# [31]	validation_0-error:0.046851	validation_1-error:0.04938
# [32]	validation_0-error:0.046474	validation_1-error:0.048989
# [33]	validation_0-error:0.046118	validation_1-error:0.048452
# [34]	validation_0-error:0.046289	validation_1-error:0.048745
# [35]	validation_0-error:0.04604	validation_1-error:0.048207
# [36]	validation_0-error:0.045893	validation_1-error:0.048207
# [37]	validation_0-error:0.045859	validation_1-error:0.048061
# [38]	validation_0-error:0.045068	validation_1-error:0.047279
# [39]	validation_0-error:0.044667	validation_1-error:0.046791
# [40]	validation_0-error:0.044506	validation_1-error:0.046645
# [41]	validation_0-error:0.044286	validation_1-error:0.046156
# [42]	validation_0-error:0.044272	validation_1-error:0.046156
# [43]	validation_0-error:0.04411	validation_1-error:0.045961
# [44]	validation_0-error:0.044067	validation_1-error:0.045912
# [45]	validation_0-error:0.044076	validation_1-error:0.045765
# [46]	validation_0-error:0.043358	validation_1-error:0.045033
# [47]	validation_0-error:0.043329	validation_1-error:0.045082
# [48]	validation_0-error:0.043324	validation_1-error:0.045082
# [49]	validation_0-error:0.043041	validation_1-error:0.044935
# [50]	validation_0-error:0.042621	validation_1-error:0.044447
# [51]	validation_0-error:0.042435	validation_1-error:0.044202
# [52]	validation_0-error:0.042337	validation_1-error:0.044105
# [53]	validation_0-error:0.04201	validation_1-error:0.043812
# [54]	validation_0-error:0.041839	validation_1-error:0.043714
# [55]	validation_0-error:0.041834	validation_1-error:0.043714
# [56]	validation_0-error:0.041737	validation_1-error:0.043812
# [57]	validation_0-error:0.041668	validation_1-error:0.043861
# [58]	validation_0-error:0.041497	validation_1-error:0.04347
# [59]	validation_0-error:0.040936	validation_1-error:0.043079
# [60]	validation_0-error:0.040555	validation_1-error:0.042444
# [61]	validation_0-error:0.040301	validation_1-error:0.042151
# [62]	validation_0-error:0.039949	validation_1-error:0.041858
# [63]	validation_0-error:0.039793	validation_1-error:0.04176
# [64]	validation_0-error:0.039588	validation_1-error:0.041516
# [65]	validation_0-error:0.039426	validation_1-error:0.041223
# [66]	validation_0-error:0.039358	validation_1-error:0.041174
# [67]	validation_0-error:0.03906	validation_1-error:0.040539
# [68]	validation_0-error:0.03885	validation_1-error:0.04049
# [69]	validation_0-error:0.038469	validation_1-error:0.039758
# [70]	validation_0-error:0.038435	validation_1-error:0.039855
# [71]	validation_0-error:0.038181	validation_1-error:0.039562
# [72]	validation_0-error:0.038122	validation_1-error:0.039562
# [73]	validation_0-error:0.037844	validation_1-error:0.039074
# [74]	validation_0-error:0.037785	validation_1-error:0.038879
# [75]	validation_0-error:0.037375	validation_1-error:0.038488
# [76]	validation_0-error:0.037111	validation_1-error:0.038292
# [77]	validation_0-error:0.037136	validation_1-error:0.038097
# [78]	validation_0-error:0.037009	validation_1-error:0.037706
# [79]	validation_0-error:0.036818	validation_1-error:0.037804
# [80]	validation_0-error:0.036559	validation_1-error:0.03756
# [81]	validation_0-error:0.036491	validation_1-error:0.037658
# [82]	validation_0-error:0.036413	validation_1-error:0.03756
# [83]	validation_0-error:0.036193	validation_1-error:0.037169
# [84]	validation_0-error:0.035963	validation_1-error:0.03712
# [85]	validation_0-error:0.035832	validation_1-error:0.037023
# [86]	validation_0-error:0.035753	validation_1-error:0.037071
# [87]	validation_0-error:0.035621	validation_1-error:0.036876
# [88]	validation_0-error:0.035494	validation_1-error:0.036876
# [89]	validation_0-error:0.035304	validation_1-error:0.036436
# [90]	validation_0-error:0.035211	validation_1-error:0.036388
# [91]	validation_0-error:0.03503	validation_1-error:0.036046
# [92]	validation_0-error:0.034987	validation_1-error:0.035899
# [93]	validation_0-error:0.034869	validation_1-error:0.035948
# [94]	validation_0-error:0.034737	validation_1-error:0.03585
# [95]	validation_0-error:0.034698	validation_1-error:0.035997
# [96]	validation_0-error:0.034532	validation_1-error:0.035802
# [97]	validation_0-error:0.034493	validation_1-error:0.03585
# [98]	validation_0-error:0.034479	validation_1-error:0.035508
# [99]	validation_0-error:0.034371	validation_1-error:0.035508
# [0]	validation_0-error:0.053352	validation_1-error:0.054655
# [1]	validation_0-error:0.051901	validation_1-error:0.053238
# [2]	validation_0-error:0.051881	validation_1-error:0.053141
# [3]	validation_0-error:0.052091	validation_1-error:0.053336
# [4]	validation_0-error:0.052272	validation_1-error:0.053482
# [5]	validation_0-error:0.059354	validation_1-error:0.060516
# [6]	validation_0-error:0.055896	validation_1-error:0.05739
# [7]	validation_0-error:0.055686	validation_1-error:0.057097
# [8]	validation_0-error:0.057723	validation_1-error:0.059002
# [9]	validation_0-error:0.057406	validation_1-error:0.058709
# [10]	validation_0-error:0.056844	validation_1-error:0.058464
# [11]	validation_0-error:0.054289	validation_1-error:0.055876
# [12]	validation_0-error:0.055721	validation_1-error:0.056853
# [13]	validation_0-error:0.053742	validation_1-error:0.055045
# [14]	validation_0-error:0.053083	validation_1-error:0.054606
# [15]	validation_0-error:0.051051	validation_1-error:0.051724
# [16]	validation_0-error:0.05195	validation_1-error:0.053092
# [17]	validation_0-error:0.052604	validation_1-error:0.053482
# [18]	validation_0-error:0.051173	validation_1-error:0.051529
# [19]	validation_0-error:0.050563	validation_1-error:0.050845
# [20]	validation_0-error:0.050084	validation_1-error:0.050601
# [21]	validation_0-error:0.049801	validation_1-error:0.050552
# [22]	validation_0-error:0.04939	validation_1-error:0.050601
# [23]	validation_0-error:0.048702	validation_1-error:0.049087
# [24]	validation_0-error:0.048658	validation_1-error:0.049135
# [25]	validation_0-error:0.047901	validation_1-error:0.048501
# [26]	validation_0-error:0.046523	validation_1-error:0.047133
# [27]	validation_0-error:0.046792	validation_1-error:0.047084
# [28]	validation_0-error:0.046137	validation_1-error:0.046791
# [29]	validation_0-error:0.046235	validation_1-error:0.046351
# [30]	validation_0-error:0.046084	validation_1-error:0.046547
# [31]	validation_0-error:0.045937	validation_1-error:0.0464
# [32]	validation_0-error:0.04604	validation_1-error:0.046498
# [33]	validation_0-error:0.0458	validation_1-error:0.046156
# [34]	validation_0-error:0.045385	validation_1-error:0.045619
# [35]	validation_0-error:0.045498	validation_1-error:0.046058
# [36]	validation_0-error:0.045419	validation_1-error:0.045961
# [37]	validation_0-error:0.045332	validation_1-error:0.045472
# [38]	validation_0-error:0.045273	validation_1-error:0.045228
# [39]	validation_0-error:0.044946	validation_1-error:0.045375
# [40]	validation_0-error:0.044858	validation_1-error:0.045375
# [41]	validation_0-error:0.04475	validation_1-error:0.045179
# [42]	validation_0-error:0.044736	validation_1-error:0.045179
# [43]	validation_0-error:0.044648	validation_1-error:0.044886
# [44]	validation_0-error:0.044106	validation_1-error:0.044202
# [45]	validation_0-error:0.044198	validation_1-error:0.044495
# [46]	validation_0-error:0.043778	validation_1-error:0.043861
# [47]	validation_0-error:0.043612	validation_1-error:0.043567
# [48]	validation_0-error:0.043471	validation_1-error:0.043274
# [49]	validation_0-error:0.043129	validation_1-error:0.042737
# [50]	validation_0-error:0.042841	validation_1-error:0.042444
# [51]	validation_0-error:0.042508	validation_1-error:0.042151
# [52]	validation_0-error:0.042425	validation_1-error:0.042395
# [53]	validation_0-error:0.042044	validation_1-error:0.041809
# [54]	validation_0-error:0.041751	validation_1-error:0.041516
# [55]	validation_0-error:0.041634	validation_1-error:0.04137
# [56]	validation_0-error:0.041527	validation_1-error:0.041321
# [57]	validation_0-error:0.041263	validation_1-error:0.041223
# [58]	validation_0-error:0.041014	validation_1-error:0.04093
# [59]	validation_0-error:0.040755	validation_1-error:0.040686
# [60]	validation_0-error:0.040706	validation_1-error:0.040539
# [61]	validation_0-error:0.040203	validation_1-error:0.040295
# [62]	validation_0-error:0.040169	validation_1-error:0.040393
# [63]	validation_0-error:0.039788	validation_1-error:0.040051
# [64]	validation_0-error:0.039485	validation_1-error:0.039855
# [65]	validation_0-error:0.039319	validation_1-error:0.039465
# [66]	validation_0-error:0.039172	validation_1-error:0.039465
# [67]	validation_0-error:0.039045	validation_1-error:0.039172
# [68]	validation_0-error:0.038909	validation_1-error:0.038781
# [69]	validation_0-error:0.03864	validation_1-error:0.038586
# [70]	validation_0-error:0.038523	validation_1-error:0.038634
# [71]	validation_0-error:0.038337	validation_1-error:0.03839
# [72]	validation_0-error:0.038269	validation_1-error:0.038244
# [73]	validation_0-error:0.037888	validation_1-error:0.037999
# [74]	validation_0-error:0.037785	validation_1-error:0.037999
# [75]	validation_0-error:0.037458	validation_1-error:0.037902
# [76]	validation_0-error:0.03739	validation_1-error:0.037609
# [77]	validation_0-error:0.037326	validation_1-error:0.03756
# [78]	validation_0-error:0.037263	validation_1-error:0.037609
# [79]	validation_0-error:0.037072	validation_1-error:0.037609
# [80]	validation_0-error:0.036852	validation_1-error:0.037218
# [81]	validation_0-error:0.03673	validation_1-error:0.037071
# [82]	validation_0-error:0.036603	validation_1-error:0.036876
# [83]	validation_0-error:0.036564	validation_1-error:0.036876
# [84]	validation_0-error:0.036256	validation_1-error:0.036583
# [85]	validation_0-error:0.036051	validation_1-error:0.036485
# [86]	validation_0-error:0.036066	validation_1-error:0.036388
# [87]	validation_0-error:0.035792	validation_1-error:0.036143
# [88]	validation_0-error:0.0357	validation_1-error:0.036192
# [89]	validation_0-error:0.035431	validation_1-error:0.035802
# [90]	validation_0-error:0.035231	validation_1-error:0.035606
# [91]	validation_0-error:0.034996	validation_1-error:0.035069
# [92]	validation_0-error:0.03483	validation_1-error:0.034922
# [93]	validation_0-error:0.034801	validation_1-error:0.034776
# [94]	validation_0-error:0.034669	validation_1-error:0.034678
# [95]	validation_0-error:0.034654	validation_1-error:0.03458
# [96]	validation_0-error:0.034503	validation_1-error:0.034483
# [97]	validation_0-error:0.034454	validation_1-error:0.034629
# [98]	validation_0-error:0.034449	validation_1-error:0.034532
# [99]	validation_0-error:0.034269	validation_1-error:0.034239
# [0]	validation_0-error:0.052204	validation_1-error:0.047133
# [1]	validation_0-error:0.051881	validation_1-error:0.046938
# [2]	validation_0-error:0.051837	validation_1-error:0.046986
# [3]	validation_0-error:0.051872	validation_1-error:0.047084
# [4]	validation_0-error:0.051881	validation_1-error:0.047377
# [5]	validation_0-error:0.052116	validation_1-error:0.047377
# [6]	validation_0-error:0.051984	validation_1-error:0.047426
# [7]	validation_0-error:0.055711	validation_1-error:0.050747
# [8]	validation_0-error:0.054939	validation_1-error:0.050015
# [9]	validation_0-error:0.055125	validation_1-error:0.050259
# [10]	validation_0-error:0.056693	validation_1-error:0.052457
# [11]	validation_0-error:0.056556	validation_1-error:0.05231
# [12]	validation_0-error:0.056922	validation_1-error:0.052652
# [13]	validation_0-error:0.056688	validation_1-error:0.052408
# [14]	validation_0-error:0.056609	validation_1-error:0.05231
# [15]	validation_0-error:0.055081	validation_1-error:0.051382
# [16]	validation_0-error:0.053205	validation_1-error:0.049917
# [17]	validation_0-error:0.052067	validation_1-error:0.048989
# [18]	validation_0-error:0.050382	validation_1-error:0.047133
# [19]	validation_0-error:0.051051	validation_1-error:0.048159
# [20]	validation_0-error:0.050934	validation_1-error:0.048403
# [21]	validation_0-error:0.050714	validation_1-error:0.047768
# [22]	validation_0-error:0.050201	validation_1-error:0.047133
# [23]	validation_0-error:0.04982	validation_1-error:0.04684
# [24]	validation_0-error:0.048697	validation_1-error:0.046351
# [25]	validation_0-error:0.048643	validation_1-error:0.046107
# [26]	validation_0-error:0.04791	validation_1-error:0.044886
# [27]	validation_0-error:0.047935	validation_1-error:0.045179
# [28]	validation_0-error:0.047544	validation_1-error:0.044544
# [29]	validation_0-error:0.047549	validation_1-error:0.044935
# [30]	validation_0-error:0.047827	validation_1-error:0.045179
# [31]	validation_0-error:0.047276	validation_1-error:0.044691
# [32]	validation_0-error:0.047202	validation_1-error:0.0443
# [33]	validation_0-error:0.046836	validation_1-error:0.044056
# [34]	validation_0-error:0.046177	validation_1-error:0.043519
# [35]	validation_0-error:0.04601	validation_1-error:0.043519
# [36]	validation_0-error:0.045991	validation_1-error:0.043421
# [37]	validation_0-error:0.045967	validation_1-error:0.043519
# [38]	validation_0-error:0.045796	validation_1-error:0.043616
# [39]	validation_0-error:0.045888	validation_1-error:0.043274
# [40]	validation_0-error:0.04584	validation_1-error:0.043323
# [41]	validation_0-error:0.045639	validation_1-error:0.043079
# [42]	validation_0-error:0.045117	validation_1-error:0.042639
# [43]	validation_0-error:0.045141	validation_1-error:0.042639
# [44]	validation_0-error:0.044716	validation_1-error:0.042395
# [45]	validation_0-error:0.044501	validation_1-error:0.042249
# [46]	validation_0-error:0.044296	validation_1-error:0.042151
# [47]	validation_0-error:0.043866	validation_1-error:0.041614
# [48]	validation_0-error:0.043773	validation_1-error:0.041711
# [49]	validation_0-error:0.043363	validation_1-error:0.040832
# [50]	validation_0-error:0.04309	validation_1-error:0.040686
# [51]	validation_0-error:0.042816	validation_1-error:0.040393
# [52]	validation_0-error:0.042401	validation_1-error:0.040197
# [53]	validation_0-error:0.042093	validation_1-error:0.039807
# [54]	validation_0-error:0.041825	validation_1-error:0.039562
# [55]	validation_0-error:0.041771	validation_1-error:0.039562
# [56]	validation_0-error:0.041742	validation_1-error:0.039514
# [57]	validation_0-error:0.041561	validation_1-error:0.039172
# [58]	validation_0-error:0.041151	validation_1-error:0.039025
# [59]	validation_0-error:0.041043	validation_1-error:0.039123
# [60]	validation_0-error:0.040477	validation_1-error:0.038586
# [61]	validation_0-error:0.040403	validation_1-error:0.038683
# [62]	validation_0-error:0.040071	validation_1-error:0.038537
# [63]	validation_0-error:0.040047	validation_1-error:0.03839
# [64]	validation_0-error:0.039739	validation_1-error:0.037902
# [65]	validation_0-error:0.039734	validation_1-error:0.037853
# [66]	validation_0-error:0.039592	validation_1-error:0.037658
# [67]	validation_0-error:0.039207	validation_1-error:0.037462
# [68]	validation_0-error:0.039041	validation_1-error:0.037462
# [69]	validation_0-error:0.038899	validation_1-error:0.037364
# [70]	validation_0-error:0.038655	validation_1-error:0.037023
# [71]	validation_0-error:0.038337	validation_1-error:0.036876
# [72]	validation_0-error:0.038205	validation_1-error:0.036778
# [73]	validation_0-error:0.038	validation_1-error:0.036583
# [74]	validation_0-error:0.037683	validation_1-error:0.036485
# [75]	validation_0-error:0.037458	validation_1-error:0.035997
# [76]	validation_0-error:0.037326	validation_1-error:0.035948
# [77]	validation_0-error:0.037307	validation_1-error:0.036046
# [78]	validation_0-error:0.037111	validation_1-error:0.03585
# [79]	validation_0-error:0.036779	validation_1-error:0.035264
# [80]	validation_0-error:0.036803	validation_1-error:0.03546
# [81]	validation_0-error:0.036642	validation_1-error:0.035167
# [82]	validation_0-error:0.036535	validation_1-error:0.034971
# [83]	validation_0-error:0.036388	validation_1-error:0.035069
# [84]	validation_0-error:0.036144	validation_1-error:0.034336
# [85]	validation_0-error:0.036037	validation_1-error:0.03419
# [86]	validation_0-error:0.036046	validation_1-error:0.034629
# [87]	validation_0-error:0.035734	validation_1-error:0.03419
# [88]	validation_0-error:0.035504	validation_1-error:0.03375
# [89]	validation_0-error:0.035382	validation_1-error:0.033799
# [90]	validation_0-error:0.035216	validation_1-error:0.03375
# [91]	validation_0-error:0.034933	validation_1-error:0.033604
# [92]	validation_0-error:0.034659	validation_1-error:0.033408
# [93]	validation_0-error:0.034532	validation_1-error:0.033017
# [94]	validation_0-error:0.034405	validation_1-error:0.032822
# [95]	validation_0-error:0.034161	validation_1-error:0.032676
# [96]	validation_0-error:0.034029	validation_1-error:0.03248
# [97]	validation_0-error:0.033941	validation_1-error:0.032578
# [98]	validation_0-error:0.033868	validation_1-error:0.032431
# [99]	validation_0-error:0.033873	validation_1-error:0.032383
# [0]	validation_0-error:0.052311	validation_1-error:0.052848
# [1]	validation_0-error:0.052585	validation_1-error:0.053043
# [2]	validation_0-error:0.05171	validation_1-error:0.05231
# [3]	validation_0-error:0.053317	validation_1-error:0.054069
# [4]	validation_0-error:0.054177	validation_1-error:0.054166
# [5]	validation_0-error:0.060561	validation_1-error:0.060613
# [6]	validation_0-error:0.05594	validation_1-error:0.055925
# [7]	validation_0-error:0.05555	validation_1-error:0.055778
# [8]	validation_0-error:0.057347	validation_1-error:0.057927
# [9]	validation_0-error:0.056473	validation_1-error:0.057194
# [10]	validation_0-error:0.056478	validation_1-error:0.057243
# [11]	validation_0-error:0.054876	validation_1-error:0.05529
# [12]	validation_0-error:0.054622	validation_1-error:0.055192
# [13]	validation_0-error:0.053957	validation_1-error:0.054606
# [14]	validation_0-error:0.053806	validation_1-error:0.054459
# [15]	validation_0-error:0.052248	validation_1-error:0.052701
# [16]	validation_0-error:0.051115	validation_1-error:0.051724
# [17]	validation_0-error:0.050455	validation_1-error:0.051236
# [18]	validation_0-error:0.049503	validation_1-error:0.050161
# [19]	validation_0-error:0.049268	validation_1-error:0.049917
# [20]	validation_0-error:0.04877	validation_1-error:0.049429
# [21]	validation_0-error:0.048892	validation_1-error:0.049135
# [22]	validation_0-error:0.047686	validation_1-error:0.048647
# [23]	validation_0-error:0.047837	validation_1-error:0.048794
# [24]	validation_0-error:0.047451	validation_1-error:0.048159
# [25]	validation_0-error:0.047803	validation_1-error:0.048891
# [26]	validation_0-error:0.047549	validation_1-error:0.048354
# [27]	validation_0-error:0.048492	validation_1-error:0.048745
# [28]	validation_0-error:0.047652	validation_1-error:0.048549
# [29]	validation_0-error:0.047456	validation_1-error:0.048305
# [30]	validation_0-error:0.047329	validation_1-error:0.048012
# [31]	validation_0-error:0.047407	validation_1-error:0.048012
# [32]	validation_0-error:0.047232	validation_1-error:0.047914
# [33]	validation_0-error:0.04667	validation_1-error:0.047475
# [34]	validation_0-error:0.046743	validation_1-error:0.047279
# [35]	validation_0-error:0.046772	validation_1-error:0.047328
# [36]	validation_0-error:0.046523	validation_1-error:0.046938
# [37]	validation_0-error:0.046411	validation_1-error:0.046791
# [38]	validation_0-error:0.046264	validation_1-error:0.046498
# [39]	validation_0-error:0.046059	validation_1-error:0.046254
# [40]	validation_0-error:0.04584	validation_1-error:0.04601
# [41]	validation_0-error:0.045918	validation_1-error:0.046058
# [42]	validation_0-error:0.045766	validation_1-error:0.045619
# [43]	validation_0-error:0.045346	validation_1-error:0.045521
# [44]	validation_0-error:0.045249	validation_1-error:0.045423
# [45]	validation_0-error:0.045141	validation_1-error:0.045277
# [46]	validation_0-error:0.044633	validation_1-error:0.04474
# [47]	validation_0-error:0.044101	validation_1-error:0.044056
# [48]	validation_0-error:0.044252	validation_1-error:0.044398
# [49]	validation_0-error:0.044003	validation_1-error:0.044105
# [50]	validation_0-error:0.043471	validation_1-error:0.043616
# [51]	validation_0-error:0.043432	validation_1-error:0.044105
# [52]	validation_0-error:0.043011	validation_1-error:0.043616
# [53]	validation_0-error:0.042572	validation_1-error:0.04303
# [54]	validation_0-error:0.04245	validation_1-error:0.042932
# [55]	validation_0-error:0.04244	validation_1-error:0.042786
# [56]	validation_0-error:0.042269	validation_1-error:0.042688
# [57]	validation_0-error:0.042123	validation_1-error:0.042688
# [58]	validation_0-error:0.041615	validation_1-error:0.042444
# [59]	validation_0-error:0.041175	validation_1-error:0.042346
# [60]	validation_0-error:0.040857	validation_1-error:0.042151
# [61]	validation_0-error:0.040774	validation_1-error:0.042053
# [62]	validation_0-error:0.040403	validation_1-error:0.04176
# [63]	validation_0-error:0.039954	validation_1-error:0.041467
# [64]	validation_0-error:0.039773	validation_1-error:0.041174
# [65]	validation_0-error:0.039671	validation_1-error:0.041125
# [66]	validation_0-error:0.039353	validation_1-error:0.040735
# [67]	validation_0-error:0.039036	validation_1-error:0.040783
# [68]	validation_0-error:0.038801	validation_1-error:0.040442
# [69]	validation_0-error:0.03864	validation_1-error:0.040197
# [70]	validation_0-error:0.038308	validation_1-error:0.039758
# [71]	validation_0-error:0.038039	validation_1-error:0.039416
# [72]	validation_0-error:0.037736	validation_1-error:0.039074
# [73]	validation_0-error:0.037512	validation_1-error:0.038634
# [74]	validation_0-error:0.037414	validation_1-error:0.038488
# [75]	validation_0-error:0.037311	validation_1-error:0.038244
# [76]	validation_0-error:0.037199	validation_1-error:0.038195
# [77]	validation_0-error:0.037219	validation_1-error:0.038244
# [78]	validation_0-error:0.036926	validation_1-error:0.037951
# [79]	validation_0-error:0.036901	validation_1-error:0.037755
# [80]	validation_0-error:0.036803	validation_1-error:0.037658
# [81]	validation_0-error:0.036559	validation_1-error:0.037609
# [82]	validation_0-error:0.03651	validation_1-error:0.037511
# [83]	validation_0-error:0.036281	validation_1-error:0.03712
# [84]	validation_0-error:0.036027	validation_1-error:0.037071
# [85]	validation_0-error:0.035861	validation_1-error:0.036925
# [86]	validation_0-error:0.03568	validation_1-error:0.036778
# [87]	validation_0-error:0.035612	validation_1-error:0.036681
# [88]	validation_0-error:0.035553	validation_1-error:0.036681
# [89]	validation_0-error:0.035382	validation_1-error:0.036485
# [90]	validation_0-error:0.035231	validation_1-error:0.036388
# [91]	validation_0-error:0.035006	validation_1-error:0.036436
# [92]	validation_0-error:0.03482	validation_1-error:0.036046
# [93]	validation_0-error:0.034796	validation_1-error:0.035997
# [94]	validation_0-error:0.034562	validation_1-error:0.03585
# [95]	validation_0-error:0.034317	validation_1-error:0.035606
# [96]	validation_0-error:0.0342	validation_1-error:0.035704
# [97]	validation_0-error:0.033985	validation_1-error:0.035606
# [98]	validation_0-error:0.033971	validation_1-error:0.035606
# [99]	validation_0-error:0.033717	validation_1-error:0.035655
# [0]	validation_0-error:0.055022	validation_1-error:0.056511
# [1]	validation_0-error:0.051955	validation_1-error:0.053385
# [2]	validation_0-error:0.051964	validation_1-error:0.053238
# [3]	validation_0-error:0.059423	validation_1-error:0.061639
# [4]	validation_0-error:0.056702	validation_1-error:0.058318
# [5]	validation_0-error:0.056898	validation_1-error:0.058367
# [6]	validation_0-error:0.058534	validation_1-error:0.060467
# [7]	validation_0-error:0.058685	validation_1-error:0.06076
# [8]	validation_0-error:0.059223	validation_1-error:0.061493
# [9]	validation_0-error:0.057411	validation_1-error:0.059637
# [10]	validation_0-error:0.055183	validation_1-error:0.05739
# [11]	validation_0-error:0.05364	validation_1-error:0.056022
# [12]	validation_0-error:0.054397	validation_1-error:0.056413
# [13]	validation_0-error:0.05257	validation_1-error:0.054215
# [14]	validation_0-error:0.051754	validation_1-error:0.053824
# [15]	validation_0-error:0.050963	validation_1-error:0.052799
# [16]	validation_0-error:0.049664	validation_1-error:0.050747
# [17]	validation_0-error:0.050274	validation_1-error:0.051773
# [18]	validation_0-error:0.050191	validation_1-error:0.052115
# [19]	validation_0-error:0.050553	validation_1-error:0.052457
# [20]	validation_0-error:0.050021	validation_1-error:0.051626
# [21]	validation_0-error:0.050392	validation_1-error:0.052652
# [22]	validation_0-error:0.05006	validation_1-error:0.05192
# [23]	validation_0-error:0.049928	validation_1-error:0.05192
# [24]	validation_0-error:0.049039	validation_1-error:0.05065
# [25]	validation_0-error:0.049132	validation_1-error:0.050943
# [26]	validation_0-error:0.048418	validation_1-error:0.049722
# [27]	validation_0-error:0.048111	validation_1-error:0.049819
# [28]	validation_0-error:0.047847	validation_1-error:0.049722
# [29]	validation_0-error:0.047529	validation_1-error:0.048989
# [30]	validation_0-error:0.046714	validation_1-error:0.048256
# [31]	validation_0-error:0.046479	validation_1-error:0.047719
# [32]	validation_0-error:0.04625	validation_1-error:0.047182
# [33]	validation_0-error:0.046484	validation_1-error:0.047524
# [34]	validation_0-error:0.046308	validation_1-error:0.047377
# [35]	validation_0-error:0.046152	validation_1-error:0.04767
# [36]	validation_0-error:0.045942	validation_1-error:0.047377
# [37]	validation_0-error:0.045908	validation_1-error:0.047719
# [38]	validation_0-error:0.045649	validation_1-error:0.047182
# [39]	validation_0-error:0.0456	validation_1-error:0.047133
# [40]	validation_0-error:0.045454	validation_1-error:0.046889
# [41]	validation_0-error:0.045459	validation_1-error:0.046791
# [42]	validation_0-error:0.045493	validation_1-error:0.046742
# [43]	validation_0-error:0.045327	validation_1-error:0.047133
# [44]	validation_0-error:0.044916	validation_1-error:0.046303
# [45]	validation_0-error:0.044726	validation_1-error:0.046205
# [46]	validation_0-error:0.044272	validation_1-error:0.045814
# [47]	validation_0-error:0.04393	validation_1-error:0.045619
# [48]	validation_0-error:0.043949	validation_1-error:0.045863
# [49]	validation_0-error:0.043764	validation_1-error:0.045717
# [50]	validation_0-error:0.043637	validation_1-error:0.045814
# [51]	validation_0-error:0.043046	validation_1-error:0.044886
# [52]	validation_0-error:0.042674	validation_1-error:0.044593
# [53]	validation_0-error:0.04245	validation_1-error:0.044202
# [54]	validation_0-error:0.042313	validation_1-error:0.044056
# [55]	validation_0-error:0.042059	validation_1-error:0.043665
# [56]	validation_0-error:0.041673	validation_1-error:0.043372
# [57]	validation_0-error:0.041673	validation_1-error:0.043274
# [58]	validation_0-error:0.041512	validation_1-error:0.043128
# [59]	validation_0-error:0.04138	validation_1-error:0.042786
# [60]	validation_0-error:0.041107	validation_1-error:0.042932
# [61]	validation_0-error:0.040716	validation_1-error:0.0422
# [62]	validation_0-error:0.040335	validation_1-error:0.041809
# [63]	validation_0-error:0.040242	validation_1-error:0.041711
# [64]	validation_0-error:0.0401	validation_1-error:0.041467
# [65]	validation_0-error:0.039988	validation_1-error:0.041418
# [66]	validation_0-error:0.039661	validation_1-error:0.041223
# [67]	validation_0-error:0.039431	validation_1-error:0.041321
# [68]	validation_0-error:0.039246	validation_1-error:0.04093
# [69]	validation_0-error:0.039187	validation_1-error:0.040637
# [70]	validation_0-error:0.038933	validation_1-error:0.04049
# [71]	validation_0-error:0.038699	validation_1-error:0.040246
# [72]	validation_0-error:0.038503	validation_1-error:0.040002
# [73]	validation_0-error:0.03821	validation_1-error:0.039416
# [74]	validation_0-error:0.037932	validation_1-error:0.039172
# [75]	validation_0-error:0.037756	validation_1-error:0.03922
# [76]	validation_0-error:0.037678	validation_1-error:0.03922
# [77]	validation_0-error:0.037707	validation_1-error:0.038879
# [78]	validation_0-error:0.037321	validation_1-error:0.038683
# [79]	validation_0-error:0.037219	validation_1-error:0.038683
# [80]	validation_0-error:0.037126	validation_1-error:0.038537
# [81]	validation_0-error:0.037053	validation_1-error:0.038586
# [82]	validation_0-error:0.037048	validation_1-error:0.038634
# [83]	validation_0-error:0.03676	validation_1-error:0.038195
# [84]	validation_0-error:0.036623	validation_1-error:0.038097
# [85]	validation_0-error:0.036447	validation_1-error:0.037755
# [86]	validation_0-error:0.036296	validation_1-error:0.037999
# [87]	validation_0-error:0.03611	validation_1-error:0.037658
# [88]	validation_0-error:0.035866	validation_1-error:0.037316
# [89]	validation_0-error:0.03568	validation_1-error:0.036925
# [90]	validation_0-error:0.035514	validation_1-error:0.03673
# [91]	validation_0-error:0.035363	validation_1-error:0.036583
# [92]	validation_0-error:0.035211	validation_1-error:0.03629
# [93]	validation_0-error:0.035167	validation_1-error:0.03629
# [94]	validation_0-error:0.035021	validation_1-error:0.036192
# [95]	validation_0-error:0.034752	validation_1-error:0.035948
# [96]	validation_0-error:0.034532	validation_1-error:0.03585
# [97]	validation_0-error:0.034396	validation_1-error:0.03585
# [98]	validation_0-error:0.034185	validation_1-error:0.035557
# [99]	validation_0-error:0.033985	validation_1-error:0.035264
# [0]	validation_0-error:0.052311	validation_1-error:0.051333
# [1]	validation_0-error:0.051911	validation_1-error:0.050796
# [2]	validation_0-error:0.051676	validation_1-error:0.050601
# [3]	validation_0-error:0.053293	validation_1-error:0.052017
# [4]	validation_0-error:0.053425	validation_1-error:0.052066
# [5]	validation_0-error:0.060917	validation_1-error:0.058904
# [6]	validation_0-error:0.0572	validation_1-error:0.056462
# [7]	validation_0-error:0.058187	validation_1-error:0.056706
# [8]	validation_0-error:0.058763	validation_1-error:0.057683
# [9]	validation_0-error:0.05701	validation_1-error:0.056266
# [10]	validation_0-error:0.056673	validation_1-error:0.055925
# [11]	validation_0-error:0.053952	validation_1-error:0.053727
# [12]	validation_0-error:0.054641	validation_1-error:0.054264
# [13]	validation_0-error:0.053049	validation_1-error:0.052799
# [14]	validation_0-error:0.052204	validation_1-error:0.051382
# [15]	validation_0-error:0.051163	validation_1-error:0.050454
# [16]	validation_0-error:0.050445	validation_1-error:0.049233
# [17]	validation_0-error:0.050441	validation_1-error:0.049233
# [18]	validation_0-error:0.049517	validation_1-error:0.048794
# [19]	validation_0-error:0.049488	validation_1-error:0.048403
# [20]	validation_0-error:0.049664	validation_1-error:0.048549
# [21]	validation_0-error:0.049791	validation_1-error:0.048794
# [22]	validation_0-error:0.049669	validation_1-error:0.048598
# [23]	validation_0-error:0.048741	validation_1-error:0.047866
# [24]	validation_0-error:0.048917	validation_1-error:0.048403
# [25]	validation_0-error:0.048111	validation_1-error:0.047621
# [26]	validation_0-error:0.04813	validation_1-error:0.04767
# [27]	validation_0-error:0.047583	validation_1-error:0.046986
# [28]	validation_0-error:0.047515	validation_1-error:0.047035
# [29]	validation_0-error:0.047188	validation_1-error:0.046645
# [30]	validation_0-error:0.04709	validation_1-error:0.046596
# [31]	validation_0-error:0.046963	validation_1-error:0.046205
# [32]	validation_0-error:0.046084	validation_1-error:0.045961
# [33]	validation_0-error:0.045825	validation_1-error:0.045863
# [34]	validation_0-error:0.045781	validation_1-error:0.045961
# [35]	validation_0-error:0.045454	validation_1-error:0.045863
# [36]	validation_0-error:0.045288	validation_1-error:0.045765
# [37]	validation_0-error:0.045073	validation_1-error:0.045619
# [38]	validation_0-error:0.045117	validation_1-error:0.045375
# [39]	validation_0-error:0.045122	validation_1-error:0.045814
# [40]	validation_0-error:0.04477	validation_1-error:0.045277
# [41]	validation_0-error:0.044633	validation_1-error:0.045033
# [42]	validation_0-error:0.044384	validation_1-error:0.04474
# [43]	validation_0-error:0.044325	validation_1-error:0.04474
# [44]	validation_0-error:0.043983	validation_1-error:0.044349
# [45]	validation_0-error:0.043749	validation_1-error:0.0443
# [46]	validation_0-error:0.0437	validation_1-error:0.044447
# [47]	validation_0-error:0.043656	validation_1-error:0.044251
# [48]	validation_0-error:0.043607	validation_1-error:0.044251
# [49]	validation_0-error:0.043383	validation_1-error:0.043861
# [50]	validation_0-error:0.043246	validation_1-error:0.04347
# [51]	validation_0-error:0.043104	validation_1-error:0.043421
# [52]	validation_0-error:0.042665	validation_1-error:0.042981
# [53]	validation_0-error:0.04243	validation_1-error:0.042737
# [54]	validation_0-error:0.042113	validation_1-error:0.042493
# [55]	validation_0-error:0.042054	validation_1-error:0.042591
# [56]	validation_0-error:0.041786	validation_1-error:0.042395
# [57]	validation_0-error:0.041541	validation_1-error:0.042249
# [58]	validation_0-error:0.041527	validation_1-error:0.0422
# [59]	validation_0-error:0.041532	validation_1-error:0.042249
# [60]	validation_0-error:0.041238	validation_1-error:0.041858
# [61]	validation_0-error:0.040941	validation_1-error:0.041516
# [62]	validation_0-error:0.040564	validation_1-error:0.041028
# [63]	validation_0-error:0.040525	validation_1-error:0.041125
# [64]	validation_0-error:0.04034	validation_1-error:0.040686
# [65]	validation_0-error:0.039978	validation_1-error:0.040246
# [66]	validation_0-error:0.039822	validation_1-error:0.039953
# [67]	validation_0-error:0.039509	validation_1-error:0.039807
# [68]	validation_0-error:0.039226	validation_1-error:0.03966
# [69]	validation_0-error:0.038977	validation_1-error:0.039269
# [70]	validation_0-error:0.038747	validation_1-error:0.038927
# [71]	validation_0-error:0.038625	validation_1-error:0.038976
# [72]	validation_0-error:0.038347	validation_1-error:0.038732
# [73]	validation_0-error:0.038152	validation_1-error:0.03839
# [74]	validation_0-error:0.038108	validation_1-error:0.038586
# [75]	validation_0-error:0.037942	validation_1-error:0.03839
# [76]	validation_0-error:0.0378	validation_1-error:0.038292
# [77]	validation_0-error:0.037683	validation_1-error:0.038097
# [78]	validation_0-error:0.037482	validation_1-error:0.038048
# [79]	validation_0-error:0.037394	validation_1-error:0.038097
# [80]	validation_0-error:0.03737	validation_1-error:0.038048
# [81]	validation_0-error:0.037209	validation_1-error:0.038048
# [82]	validation_0-error:0.037062	validation_1-error:0.037999
# [83]	validation_0-error:0.036891	validation_1-error:0.037755
# [84]	validation_0-error:0.036637	validation_1-error:0.037364
# [85]	validation_0-error:0.036418	validation_1-error:0.037218
# [86]	validation_0-error:0.036183	validation_1-error:0.036827
# [87]	validation_0-error:0.035998	validation_1-error:0.036632
# [88]	validation_0-error:0.035846	validation_1-error:0.036046
# [89]	validation_0-error:0.035641	validation_1-error:0.035948
# [90]	validation_0-error:0.035465	validation_1-error:0.035802
# [91]	validation_0-error:0.035353	validation_1-error:0.035802
# [92]	validation_0-error:0.035177	validation_1-error:0.035508
# [93]	validation_0-error:0.035021	validation_1-error:0.035704
# [94]	validation_0-error:0.034879	validation_1-error:0.035508
# [95]	validation_0-error:0.034811	validation_1-error:0.035362
# [96]	validation_0-error:0.034606	validation_1-error:0.035264
# [97]	validation_0-error:0.034483	validation_1-error:0.03546
# [98]	validation_0-error:0.034396	validation_1-error:0.035411
# [99]	validation_0-error:0.034229	validation_1-error:0.035411
# [0]	validation_0-error:0.052497	validation_1-error:0.053387
# [1]	validation_0-error:0.052228	validation_1-error:0.053192
# [2]	validation_0-error:0.051833	validation_1-error:0.052362
# [3]	validation_0-error:0.052301	validation_1-error:0.053143
# [4]	validation_0-error:0.052389	validation_1-error:0.053241
# [5]	validation_0-error:0.055144	validation_1-error:0.055439
# [6]	validation_0-error:0.056795	validation_1-error:0.057002
# [7]	validation_0-error:0.057596	validation_1-error:0.057686
# [8]	validation_0-error:0.057743	validation_1-error:0.057735
# [9]	validation_0-error:0.057581	validation_1-error:0.057783
# [10]	validation_0-error:0.056995	validation_1-error:0.057002
# [11]	validation_0-error:0.056321	validation_1-error:0.056562
# [12]	validation_0-error:0.055945	validation_1-error:0.056123
# [13]	validation_0-error:0.054294	validation_1-error:0.054657
# [14]	validation_0-error:0.054622	validation_1-error:0.055341
# [15]	validation_0-error:0.052233	validation_1-error:0.052606
# [16]	validation_0-error:0.053254	validation_1-error:0.053583
# [17]	validation_0-error:0.051271	validation_1-error:0.051922
# [18]	validation_0-error:0.050055	validation_1-error:0.050896
# [19]	validation_0-error:0.050265	validation_1-error:0.050701
# [20]	validation_0-error:0.050909	validation_1-error:0.051482
# [21]	validation_0-error:0.050695	validation_1-error:0.051531
# [22]	validation_0-error:0.050626	validation_1-error:0.051531
# [23]	validation_0-error:0.050558	validation_1-error:0.051434
# [24]	validation_0-error:0.049713	validation_1-error:0.050799
# [25]	validation_0-error:0.049088	validation_1-error:0.049968
# [26]	validation_0-error:0.049229	validation_1-error:0.049675
# [27]	validation_0-error:0.049039	validation_1-error:0.049577
# [28]	validation_0-error:0.04897	validation_1-error:0.049724
# [29]	validation_0-error:0.049112	validation_1-error:0.049968
# [30]	validation_0-error:0.048077	validation_1-error:0.048259
# [31]	validation_0-error:0.048365	validation_1-error:0.048698
# [32]	validation_0-error:0.048472	validation_1-error:0.049431
# [33]	validation_0-error:0.047378	validation_1-error:0.047086
# [34]	validation_0-error:0.047613	validation_1-error:0.047428
# [35]	validation_0-error:0.047554	validation_1-error:0.047477
# [36]	validation_0-error:0.047276	validation_1-error:0.046891
# [37]	validation_0-error:0.046841	validation_1-error:0.046354
# [38]	validation_0-error:0.04668	validation_1-error:0.046207
# [39]	validation_0-error:0.046704	validation_1-error:0.046451
# [40]	validation_0-error:0.045957	validation_1-error:0.046012
# [41]	validation_0-error:0.045727	validation_1-error:0.045523
# [42]	validation_0-error:0.045302	validation_1-error:0.045035
# [43]	validation_0-error:0.045156	validation_1-error:0.044937
# [44]	validation_0-error:0.044794	validation_1-error:0.044498
# [45]	validation_0-error:0.044755	validation_1-error:0.044595
# [46]	validation_0-error:0.04457	validation_1-error:0.044742
# [47]	validation_0-error:0.044286	validation_1-error:0.044546
# [48]	validation_0-error:0.043822	validation_1-error:0.04396
# [49]	validation_0-error:0.043725	validation_1-error:0.043814
# [50]	validation_0-error:0.043544	validation_1-error:0.043716
# [51]	validation_0-error:0.043432	validation_1-error:0.043423
# [52]	validation_0-error:0.04308	validation_1-error:0.043325
# [53]	validation_0-error:0.042572	validation_1-error:0.04269
# [54]	validation_0-error:0.042435	validation_1-error:0.042544
# [55]	validation_0-error:0.042303	validation_1-error:0.042348
# [56]	validation_0-error:0.041942	validation_1-error:0.042202
# [57]	validation_0-error:0.041517	validation_1-error:0.041958
# [58]	validation_0-error:0.0414	validation_1-error:0.041811
# [59]	validation_0-error:0.041238	validation_1-error:0.041713
# [60]	validation_0-error:0.041009	validation_1-error:0.041762
# [61]	validation_0-error:0.040657	validation_1-error:0.041225
# [62]	validation_0-error:0.04035	validation_1-error:0.040883
# [63]	validation_0-error:0.040037	validation_1-error:0.040639
# [64]	validation_0-error:0.03991	validation_1-error:0.040297
# [65]	validation_0-error:0.039602	validation_1-error:0.039857
# [66]	validation_0-error:0.039548	validation_1-error:0.039857
# [67]	validation_0-error:0.039343	validation_1-error:0.039613
# [68]	validation_0-error:0.039202	validation_1-error:0.039564
# [69]	validation_0-error:0.038752	validation_1-error:0.038978
# [70]	validation_0-error:0.038528	validation_1-error:0.039174
# [71]	validation_0-error:0.038249	validation_1-error:0.038929
# [72]	validation_0-error:0.038078	validation_1-error:0.038636
# [73]	validation_0-error:0.037854	validation_1-error:0.038392
# [74]	validation_0-error:0.037692	validation_1-error:0.038294
# [75]	validation_0-error:0.037546	validation_1-error:0.03805
# [76]	validation_0-error:0.037424	validation_1-error:0.037952
# [77]	validation_0-error:0.037263	validation_1-error:0.037757
# [78]	validation_0-error:0.036974	validation_1-error:0.037366
# [79]	validation_0-error:0.036818	validation_1-error:0.037513
# [80]	validation_0-error:0.036574	validation_1-error:0.037269
# [81]	validation_0-error:0.036403	validation_1-error:0.037269
# [82]	validation_0-error:0.036271	validation_1-error:0.037073
# [83]	validation_0-error:0.036354	validation_1-error:0.037122
# [84]	validation_0-error:0.036237	validation_1-error:0.037073
# [85]	validation_0-error:0.036037	validation_1-error:0.037122
# [86]	validation_0-error:0.035744	validation_1-error:0.036927
# [87]	validation_0-error:0.035553	validation_1-error:0.036585
# [88]	validation_0-error:0.03548	validation_1-error:0.036389
# [89]	validation_0-error:0.035407	validation_1-error:0.036341
# [90]	validation_0-error:0.035348	validation_1-error:0.036292
# [91]	validation_0-error:0.03528	validation_1-error:0.036292
# [92]	validation_0-error:0.035192	validation_1-error:0.035999
# [93]	validation_0-error:0.034938	validation_1-error:0.035657
# [94]	validation_0-error:0.034835	validation_1-error:0.035608
# [95]	validation_0-error:0.034874	validation_1-error:0.035803
# [96]	validation_0-error:0.034698	validation_1-error:0.035412
# [97]	validation_0-error:0.034547	validation_1-error:0.035217
# [98]	validation_0-error:0.034317	validation_1-error:0.035364
# [99]	validation_0-error:0.034371	validation_1-error:0.035412
# [0]	validation_0-error:0.052311	validation_1-error:0.052606
# [1]	validation_0-error:0.052043	validation_1-error:0.052215
# [2]	validation_0-error:0.051974	validation_1-error:0.05202
# [3]	validation_0-error:0.051769	validation_1-error:0.051678
# [4]	validation_0-error:0.051877	validation_1-error:0.05202
# [5]	validation_0-error:0.053098	validation_1-error:0.052948
# [6]	validation_0-error:0.053024	validation_1-error:0.05285
# [7]	validation_0-error:0.053982	validation_1-error:0.053534
# [8]	validation_0-error:0.056087	validation_1-error:0.055683
# [9]	validation_0-error:0.057606	validation_1-error:0.057442
# [10]	validation_0-error:0.056956	validation_1-error:0.056855
# [11]	validation_0-error:0.055799	validation_1-error:0.055488
# [12]	validation_0-error:0.053669	validation_1-error:0.053876
# [13]	validation_0-error:0.055266	validation_1-error:0.055488
# [14]	validation_0-error:0.055286	validation_1-error:0.05539
# [15]	validation_0-error:0.053059	validation_1-error:0.053339
# [16]	validation_0-error:0.050949	validation_1-error:0.051336
# [17]	validation_0-error:0.050187	validation_1-error:0.050847
# [18]	validation_0-error:0.049908	validation_1-error:0.050554
# [19]	validation_0-error:0.048965	validation_1-error:0.049529
# [20]	validation_0-error:0.048721	validation_1-error:0.049284
# [21]	validation_0-error:0.04898	validation_1-error:0.049187
# [22]	validation_0-error:0.049107	validation_1-error:0.04948
# [23]	validation_0-error:0.048917	validation_1-error:0.049138
# [24]	validation_0-error:0.049073	validation_1-error:0.049138
# [25]	validation_0-error:0.049005	validation_1-error:0.048943
# [26]	validation_0-error:0.048882	validation_1-error:0.048649
# [27]	validation_0-error:0.048741	validation_1-error:0.048601
# [28]	validation_0-error:0.048501	validation_1-error:0.048601
# [29]	validation_0-error:0.048086	validation_1-error:0.048112
# [30]	validation_0-error:0.047403	validation_1-error:0.047624
# [31]	validation_0-error:0.046704	validation_1-error:0.046793
# [32]	validation_0-error:0.046753	validation_1-error:0.047038
# [33]	validation_0-error:0.046719	validation_1-error:0.046696
# [34]	validation_0-error:0.046514	validation_1-error:0.046403
# [35]	validation_0-error:0.046274	validation_1-error:0.046158
# [36]	validation_0-error:0.046059	validation_1-error:0.045963
# [37]	validation_0-error:0.046196	validation_1-error:0.046061
# [38]	validation_0-error:0.045791	validation_1-error:0.045865
# [39]	validation_0-error:0.045791	validation_1-error:0.045621
# [40]	validation_0-error:0.045634	validation_1-error:0.045768
# [41]	validation_0-error:0.045263	validation_1-error:0.045133
# [42]	validation_0-error:0.044995	validation_1-error:0.044937
# [43]	validation_0-error:0.044951	validation_1-error:0.044937
# [44]	validation_0-error:0.044877	validation_1-error:0.044693
# [45]	validation_0-error:0.044511	validation_1-error:0.044742
# [46]	validation_0-error:0.04434	validation_1-error:0.044595
# [47]	validation_0-error:0.043944	validation_1-error:0.044156
# [48]	validation_0-error:0.043764	validation_1-error:0.044205
# [49]	validation_0-error:0.043563	validation_1-error:0.043814
# [50]	validation_0-error:0.043485	validation_1-error:0.043716
# [51]	validation_0-error:0.043021	validation_1-error:0.042935
# [52]	validation_0-error:0.042928	validation_1-error:0.043081
# [53]	validation_0-error:0.042679	validation_1-error:0.042544
# [54]	validation_0-error:0.042201	validation_1-error:0.0423
# [55]	validation_0-error:0.042074	validation_1-error:0.041909
# [56]	validation_0-error:0.041903	validation_1-error:0.041811
# [57]	validation_0-error:0.041419	validation_1-error:0.041713
# [58]	validation_0-error:0.040911	validation_1-error:0.041225
# [59]	validation_0-error:0.040662	validation_1-error:0.04103
# [60]	validation_0-error:0.040491	validation_1-error:0.040785
# [61]	validation_0-error:0.040218	validation_1-error:0.040541
# [62]	validation_0-error:0.039954	validation_1-error:0.04059
# [63]	validation_0-error:0.039719	validation_1-error:0.040492
# [64]	validation_0-error:0.03947	validation_1-error:0.040346
# [65]	validation_0-error:0.039324	validation_1-error:0.040199
# [66]	validation_0-error:0.03907	validation_1-error:0.039906
# [67]	validation_0-error:0.038923	validation_1-error:0.039711
# [68]	validation_0-error:0.038821	validation_1-error:0.039515
# [69]	validation_0-error:0.038567	validation_1-error:0.039271
# [70]	validation_0-error:0.038293	validation_1-error:0.03888
# [71]	validation_0-error:0.038142	validation_1-error:0.038734
# [72]	validation_0-error:0.03781	validation_1-error:0.03849
# [73]	validation_0-error:0.037834	validation_1-error:0.038392
# [74]	validation_0-error:0.037526	validation_1-error:0.038148
# [75]	validation_0-error:0.037282	validation_1-error:0.037952
# [76]	validation_0-error:0.037175	validation_1-error:0.037659
# [77]	validation_0-error:0.036935	validation_1-error:0.037611
# [78]	validation_0-error:0.036628	validation_1-error:0.037317
# [79]	validation_0-error:0.036476	validation_1-error:0.037024
# [80]	validation_0-error:0.036408	validation_1-error:0.037269
# [81]	validation_0-error:0.036344	validation_1-error:0.037171
# [82]	validation_0-error:0.036149	validation_1-error:0.03722
# [83]	validation_0-error:0.035915	validation_1-error:0.036731
# [84]	validation_0-error:0.035734	validation_1-error:0.036536
# [85]	validation_0-error:0.035626	validation_1-error:0.036389
# [86]	validation_0-error:0.035553	validation_1-error:0.036487
# [87]	validation_0-error:0.035338	validation_1-error:0.036389
# [88]	validation_0-error:0.035192	validation_1-error:0.036243
# [89]	validation_0-error:0.035255	validation_1-error:0.036292
# [90]	validation_0-error:0.035138	validation_1-error:0.036389
# [91]	validation_0-error:0.035074	validation_1-error:0.036341
# [92]	validation_0-error:0.034987	validation_1-error:0.036194
# [93]	validation_0-error:0.034835	validation_1-error:0.035706
# [94]	validation_0-error:0.034772	validation_1-error:0.035754
# [95]	validation_0-error:0.034659	validation_1-error:0.035461
# [96]	validation_0-error:0.034547	validation_1-error:0.035364
# [97]	validation_0-error:0.034396	validation_1-error:0.035217
# [98]	validation_0-error:0.034288	validation_1-error:0.035168
# [99]	validation_0-error:0.034322	validation_1-error:0.035217
# [0]	validation_0-error:0.051925	validation_1-error:0.051873
# [1]	validation_0-error:0.051877	validation_1-error:0.051873
# [2]	validation_0-error:0.051891	validation_1-error:0.051971
# [3]	validation_0-error:0.051833	validation_1-error:0.051824
# [4]	validation_0-error:0.051852	validation_1-error:0.051824
# [5]	validation_0-error:0.055046	validation_1-error:0.054315
# [6]	validation_0-error:0.056609	validation_1-error:0.056123
# [7]	validation_0-error:0.056448	validation_1-error:0.05622
# [8]	validation_0-error:0.057108	validation_1-error:0.056513
# [9]	validation_0-error:0.055804	validation_1-error:0.055292
# [10]	validation_0-error:0.056595	validation_1-error:0.055781
# [11]	validation_0-error:0.054285	validation_1-error:0.053241
# [12]	validation_0-error:0.054934	validation_1-error:0.054218
# [13]	validation_0-error:0.056018	validation_1-error:0.055585
# [14]	validation_0-error:0.054441	validation_1-error:0.053583
# [15]	validation_0-error:0.05321	validation_1-error:0.052264
# [16]	validation_0-error:0.052082	validation_1-error:0.051092
# [17]	validation_0-error:0.051877	validation_1-error:0.050945
# [18]	validation_0-error:0.050211	validation_1-error:0.048552
# [19]	validation_0-error:0.049625	validation_1-error:0.048161
# [20]	validation_0-error:0.049376	validation_1-error:0.04821
# [21]	validation_0-error:0.049767	validation_1-error:0.049089
# [22]	validation_0-error:0.049952	validation_1-error:0.048845
# [23]	validation_0-error:0.049918	validation_1-error:0.048943
# [24]	validation_0-error:0.049654	validation_1-error:0.048601
# [25]	validation_0-error:0.049161	validation_1-error:0.048161
# [26]	validation_0-error:0.049298	validation_1-error:0.047966
# [27]	validation_0-error:0.048057	validation_1-error:0.046793
# [28]	validation_0-error:0.047994	validation_1-error:0.046647
# [29]	validation_0-error:0.047847	validation_1-error:0.046451
# [30]	validation_0-error:0.047569	validation_1-error:0.046403
# [31]	validation_0-error:0.047192	validation_1-error:0.045914
# [32]	validation_0-error:0.047022	validation_1-error:0.046061
# [33]	validation_0-error:0.047236	validation_1-error:0.046451
# [34]	validation_0-error:0.047109	validation_1-error:0.0465
# [35]	validation_0-error:0.04686	validation_1-error:0.045719
# [36]	validation_0-error:0.046758	validation_1-error:0.045914
# [37]	validation_0-error:0.046968	validation_1-error:0.046305
# [38]	validation_0-error:0.046621	validation_1-error:0.045816
# [39]	validation_0-error:0.046582	validation_1-error:0.046158
# [40]	validation_0-error:0.046357	validation_1-error:0.045865
# [41]	validation_0-error:0.046108	validation_1-error:0.045328
# [42]	validation_0-error:0.04604	validation_1-error:0.045279
# [43]	validation_0-error:0.045879	validation_1-error:0.045181
# [44]	validation_0-error:0.045796	validation_1-error:0.045035
# [45]	validation_0-error:0.045405	validation_1-error:0.044742
# [46]	validation_0-error:0.044853	validation_1-error:0.044107
# [47]	validation_0-error:0.04434	validation_1-error:0.043374
# [48]	validation_0-error:0.04413	validation_1-error:0.043228
# [49]	validation_0-error:0.043876	validation_1-error:0.04313
# [50]	validation_0-error:0.043803	validation_1-error:0.043032
# [51]	validation_0-error:0.043656	validation_1-error:0.043081
# [52]	validation_0-error:0.043417	validation_1-error:0.042935
# [53]	validation_0-error:0.043104	validation_1-error:0.042495
# [54]	validation_0-error:0.042914	validation_1-error:0.042446
# [55]	validation_0-error:0.042469	validation_1-error:0.042007
# [56]	validation_0-error:0.041956	validation_1-error:0.04142
# [57]	validation_0-error:0.041639	validation_1-error:0.041078
# [58]	validation_0-error:0.041019	validation_1-error:0.040346
# [59]	validation_0-error:0.040745	validation_1-error:0.039857
# [60]	validation_0-error:0.04052	validation_1-error:0.039906
# [61]	validation_0-error:0.040442	validation_1-error:0.03976
# [62]	validation_0-error:0.040369	validation_1-error:0.039809
# [63]	validation_0-error:0.039929	validation_1-error:0.039271
# [64]	validation_0-error:0.039783	validation_1-error:0.039222
# [65]	validation_0-error:0.0395	validation_1-error:0.039076
# [66]	validation_0-error:0.039265	validation_1-error:0.038783
# [67]	validation_0-error:0.039045	validation_1-error:0.038587
# [68]	validation_0-error:0.03883	validation_1-error:0.038099
# [69]	validation_0-error:0.038655	validation_1-error:0.037904
# [70]	validation_0-error:0.038357	validation_1-error:0.037562
# [71]	validation_0-error:0.038049	validation_1-error:0.036976
# [72]	validation_0-error:0.037761	validation_1-error:0.036682
# [73]	validation_0-error:0.037766	validation_1-error:0.036536
# [74]	validation_0-error:0.037502	validation_1-error:0.036145
# [75]	validation_0-error:0.037399	validation_1-error:0.03595
# [76]	validation_0-error:0.037272	validation_1-error:0.035657
# [77]	validation_0-error:0.037048	validation_1-error:0.035559
# [78]	validation_0-error:0.036794	validation_1-error:0.03551
# [79]	validation_0-error:0.036628	validation_1-error:0.035315
# [80]	validation_0-error:0.036369	validation_1-error:0.035022
# [81]	validation_0-error:0.036115	validation_1-error:0.034875
# [82]	validation_0-error:0.036178	validation_1-error:0.034924
# [83]	validation_0-error:0.036046	validation_1-error:0.034778
# [84]	validation_0-error:0.0359	validation_1-error:0.034778
# [85]	validation_0-error:0.035621	validation_1-error:0.034875
# [86]	validation_0-error:0.035543	validation_1-error:0.034826
# [87]	validation_0-error:0.035431	validation_1-error:0.034582
# [88]	validation_0-error:0.035348	validation_1-error:0.034338
# [89]	validation_0-error:0.035255	validation_1-error:0.034387
# [90]	validation_0-error:0.035026	validation_1-error:0.03424
# [91]	validation_0-error:0.035016	validation_1-error:0.034143
# [92]	validation_0-error:0.034943	validation_1-error:0.034094
# [93]	validation_0-error:0.034776	validation_1-error:0.033898
# [94]	validation_0-error:0.034562	validation_1-error:0.033556
# [95]	validation_0-error:0.034474	validation_1-error:0.033605
# [96]	validation_0-error:0.034479	validation_1-error:0.033605
# [97]	validation_0-error:0.034464	validation_1-error:0.033849
# [98]	validation_0-error:0.034273	validation_1-error:0.033556
# [99]	validation_0-error:0.034166	validation_1-error:0.03341
# [0]	validation_0-error:0.052526	validation_1-error:0.053339
# [1]	validation_0-error:0.051877	validation_1-error:0.052801
# [2]	validation_0-error:0.052052	validation_1-error:0.053143
# [3]	validation_0-error:0.051921	validation_1-error:0.052997
# [4]	validation_0-error:0.05194	validation_1-error:0.053143
# [5]	validation_0-error:0.054827	validation_1-error:0.05583
# [6]	validation_0-error:0.056473	validation_1-error:0.057148
# [7]	validation_0-error:0.057791	validation_1-error:0.058467
# [8]	validation_0-error:0.058168	validation_1-error:0.058809
# [9]	validation_0-error:0.057117	validation_1-error:0.058076
# [10]	validation_0-error:0.057303	validation_1-error:0.058272
# [11]	validation_0-error:0.055706	validation_1-error:0.056953
# [12]	validation_0-error:0.053469	validation_1-error:0.054462
# [13]	validation_0-error:0.05428	validation_1-error:0.055146
# [14]	validation_0-error:0.054797	validation_1-error:0.055683
# [15]	validation_0-error:0.053225	validation_1-error:0.054071
# [16]	validation_0-error:0.051569	validation_1-error:0.051922
# [17]	validation_0-error:0.050739	validation_1-error:0.051189
# [18]	validation_0-error:0.049884	validation_1-error:0.05031
# [19]	validation_0-error:0.049859	validation_1-error:0.050457
# [20]	validation_0-error:0.049918	validation_1-error:0.05031
# [21]	validation_0-error:0.050079	validation_1-error:0.050799
# [22]	validation_0-error:0.050397	validation_1-error:0.051043
# [23]	validation_0-error:0.050504	validation_1-error:0.051043
# [24]	validation_0-error:0.049854	validation_1-error:0.050457
# [25]	validation_0-error:0.049537	validation_1-error:0.050506
# [26]	validation_0-error:0.049669	validation_1-error:0.050408
# [27]	validation_0-error:0.048477	validation_1-error:0.049236
# [28]	validation_0-error:0.048418	validation_1-error:0.049187
# [29]	validation_0-error:0.048169	validation_1-error:0.049187
# [30]	validation_0-error:0.047808	validation_1-error:0.049236
# [31]	validation_0-error:0.047774	validation_1-error:0.048845
# [32]	validation_0-error:0.047656	validation_1-error:0.048698
# [33]	validation_0-error:0.0473	validation_1-error:0.048063
# [34]	validation_0-error:0.047222	validation_1-error:0.047819
# [35]	validation_0-error:0.04688	validation_1-error:0.047868
# [36]	validation_0-error:0.046621	validation_1-error:0.047868
# [37]	validation_0-error:0.046611	validation_1-error:0.047477
# [38]	validation_0-error:0.046123	validation_1-error:0.04694
# [39]	validation_0-error:0.045952	validation_1-error:0.046989
# [40]	validation_0-error:0.045634	validation_1-error:0.046354
# [41]	validation_0-error:0.045527	validation_1-error:0.046403
# [42]	validation_0-error:0.045165	validation_1-error:0.045572
# [43]	validation_0-error:0.045156	validation_1-error:0.045865
# [44]	validation_0-error:0.044965	validation_1-error:0.045084
# [45]	validation_0-error:0.044496	validation_1-error:0.044888
# [46]	validation_0-error:0.044325	validation_1-error:0.044888
# [47]	validation_0-error:0.044233	validation_1-error:0.044986
# [48]	validation_0-error:0.044086	validation_1-error:0.044644
# [49]	validation_0-error:0.043627	validation_1-error:0.043716
# [50]	validation_0-error:0.043305	validation_1-error:0.043667
# [51]	validation_0-error:0.043148	validation_1-error:0.042983
# [52]	validation_0-error:0.042894	validation_1-error:0.042983
# [53]	validation_0-error:0.042591	validation_1-error:0.042544
# [54]	validation_0-error:0.042406	validation_1-error:0.042544
# [55]	validation_0-error:0.042259	validation_1-error:0.042348
# [56]	validation_0-error:0.041751	validation_1-error:0.041713
# [57]	validation_0-error:0.041312	validation_1-error:0.041176
# [58]	validation_0-error:0.040809	validation_1-error:0.040785
# [59]	validation_0-error:0.04052	validation_1-error:0.04059
# [60]	validation_0-error:0.040433	validation_1-error:0.040444
# [61]	validation_0-error:0.039861	validation_1-error:0.039613
# [62]	validation_0-error:0.039558	validation_1-error:0.03932
# [63]	validation_0-error:0.039505	validation_1-error:0.039271
# [64]	validation_0-error:0.039343	validation_1-error:0.039369
# [65]	validation_0-error:0.039172	validation_1-error:0.039271
# [66]	validation_0-error:0.038967	validation_1-error:0.038978
# [67]	validation_0-error:0.038796	validation_1-error:0.038978
# [68]	validation_0-error:0.038474	validation_1-error:0.038734
# [69]	validation_0-error:0.038073	validation_1-error:0.038539
# [70]	validation_0-error:0.038098	validation_1-error:0.038441
# [71]	validation_0-error:0.037854	validation_1-error:0.038197
# [72]	validation_0-error:0.037639	validation_1-error:0.037904
# [73]	validation_0-error:0.03757	validation_1-error:0.037952
# [74]	validation_0-error:0.037434	validation_1-error:0.037806
# [75]	validation_0-error:0.037341	validation_1-error:0.037611
# [76]	validation_0-error:0.037136	validation_1-error:0.037317
# [77]	validation_0-error:0.03693	validation_1-error:0.037171
# [78]	validation_0-error:0.03672	validation_1-error:0.037122
# [79]	validation_0-error:0.036564	validation_1-error:0.036927
# [80]	validation_0-error:0.036261	validation_1-error:0.036487
# [81]	validation_0-error:0.036208	validation_1-error:0.036438
# [82]	validation_0-error:0.036056	validation_1-error:0.036292
# [83]	validation_0-error:0.035802	validation_1-error:0.035999
# [84]	validation_0-error:0.035841	validation_1-error:0.035852
# [85]	validation_0-error:0.035709	validation_1-error:0.035657
# [86]	validation_0-error:0.035509	validation_1-error:0.035754
# [87]	validation_0-error:0.035397	validation_1-error:0.03595
# [88]	validation_0-error:0.035299	validation_1-error:0.035754
# [89]	validation_0-error:0.035255	validation_1-error:0.03551
# [90]	validation_0-error:0.035197	validation_1-error:0.035461
# [91]	validation_0-error:0.035079	validation_1-error:0.035412
# [92]	validation_0-error:0.034938	validation_1-error:0.035217
# [93]	validation_0-error:0.034747	validation_1-error:0.035266
# [94]	validation_0-error:0.034503	validation_1-error:0.034924
# [95]	validation_0-error:0.034366	validation_1-error:0.034875
# [96]	validation_0-error:0.034132	validation_1-error:0.034826
# [97]	validation_0-error:0.034015	validation_1-error:0.034778
# [98]	validation_0-error:0.033892	validation_1-error:0.034631
# [99]	validation_0-error:0.0338	validation_1-error:0.034729
# Roc-auc score with Catboost: 0.9847568789619157

# %%
pred
# Out:
# [array([0.96577   , 0.9890392 , 0.9629396 , ..., 0.05404733, 0.98394716,
#         0.9895839 ], dtype=float32),
#  array([0.9632713 , 0.98568106, 0.96334857, ..., 0.05304264, 0.9850036 ,
#         0.9918046 ], dtype=float32),
#  array([0.96326935, 0.98893857, 0.95778733, ..., 0.06200124, 0.9807358 ,
#         0.9901419 ], dtype=float32),
#  array([0.965991  , 0.99026275, 0.9519397 , ..., 0.04039519, 0.9854866 ,
#         0.99223125], dtype=float32),
#  array([0.9660719 , 0.9933989 , 0.95865345, ..., 0.05288278, 0.9848519 ,
#         0.99245876], dtype=float32),
#  array([0.964028  , 0.99009925, 0.9551687 , ..., 0.06963506, 0.98472184,
#         0.99207944], dtype=float32),
#  array([0.9657457 , 0.9898722 , 0.9732912 , ..., 0.05745121, 0.98587555,
#         0.9913833 ], dtype=float32),
#  array([0.96915764, 0.9930483 , 0.9639168 , ..., 0.04839014, 0.98587877,
#         0.9933182 ], dtype=float32),
#  array([0.96786755, 0.990559  , 0.9639224 , ..., 0.05167852, 0.98421496,
#         0.9916121 ], dtype=float32),
#  array([0.9689437 , 0.9910932 , 0.9633446 , ..., 0.06396124, 0.98615754,
#         0.9930079 ], dtype=float32)]

# %%
precision = precision_score(y_test, pred)
recall = recall_score(y_test, pred)
acc = accuracy_score(y_test, pred)
cm = confusion_matrix(y_test, pred)
print('Precision:', precision)
print('Recall:', recall)
print('Accuracy:', acc)
print('Confusion Matrix:', cm)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-1937dff49b36> in <module>
# ----> 1 precision = precision_score(y_test, pred)
#       2 recall = recall_score(y_test, pred)
#       3 acc = accuracy_score(y_test, pred)
#       4 cm = confusion_matrix(y_test, pred)
#       5 print('Precision:', precision)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1670                                                  warn_for=('precision',),
#    1671                                                  sample_weight=sample_weight,
# -> 1672                                                  zero_division=zero_division)
#    1673     return p
#    1674
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1482         raise ValueError("beta should be >=0 in the F-beta score")
#    1483     labels = _check_set_wise_labels(y_true, y_pred, average, labels,
# -> 1484                                     pos_label)
#    1485
#    1486     # Calculate tp_sum, pred_sum, true_sum ###
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1299                          str(average_options))
#    1300
# -> 1301     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1302     present_labels = unique_labels(y_true, y_pred)
#    1303     if average == 'binary':
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      78     y_pred : array or indicator matrix
#      79     """
# ---> 80     check_consistent_length(y_true, y_pred)
#      81     type_true = type_of_target(y_true)
#      82     type_pred = type_of_target(y_pred)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     210     if len(uniques) > 1:
#     211         raise ValueError("Found input variables with inconsistent numbers of"
# --> 212                          " samples: %r" % [int(l) for l in lengths])
#     213
#     214
#
# ValueError: Found input variables with inconsistent numbers of samples: [22749, 10]

# %%
X_test_new = pd.read_csv('X_test.csv')

y_test_new = pd.read_csv('y_test.csv')

# %%
y_pred = xgb_c1.predict(X_test_new)
    

precision = precision_score(y_test_new, y_pred)
recall = recall_score(y_test_new, y_pred)
acc = accuracy_score(y_test_new, y_pred)
cm = confusion_matrix(y_test_new, y_pred)
print('Precision:', precision)
print('Recall:', recall)
print('Accuracy:', acc)
print('Confusion Matrix:', cm)
